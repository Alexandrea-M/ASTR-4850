# %% [markdown]
# ## Magnitude error from Howell 2006:
# ## $\sigma_{magnitudes}=\frac{1.0857 \sqrt{N_* + p}}{N_*} $
# ## $p = n_{pix} (1+ \frac{n_{pix}}{n_B})(N_S + N_D + N_R^2 +G^2\sigma_f^2)$
# #### $n_{pix} =$ number of pixels in source region
# #### $n_B =$ number of background pixels used to estimate the meal level of the background
# #### $N_S =$ total number of photons per pixel from the background/sky
# #### $N_D =$ total number of dark current electrons per pixel
# #### $N_R^2 =$ total number of electrons per pixel resulting from the read noise
# #### $G =$ gain of the CCD
# #### $\sigma_f^2 =$ 1 sigma error introduced within the A/D converter ~ 0.289

# %%
import numpy as np

# Returns full SNR calculation
def snr(N_star, n_pix, n_B, N_S, N_D, N_R, G, sigma_f=0.289):
    p = n_pix * (1 + n_pix / n_B) * (N_S + N_D + N_R**2 + G**2 * sigma_f**2)
    snr_value = N_star / np.sqrt(N_star + p)
    return snr_value

# Returns SNR estimate based on photon counts
def snr_est(N_star):
    return np.sqrt(N_star)

# Returns magnitude error for a given SNR
def mag_error(snr):
    return 1.0857 / snr

# Returns minimum SNR for a given magnitude error
def min_snr(mag_err):
    return 1.0857 / mag_err

# Returns photon counts per second based on zero point magnitude and target magnitude
def photon_counts_per_sec(zpmag, target_mag):
    return 2.5**(zpmag - target_mag)

# %% [markdown]
# ## RLMT Estimates

# %%
from glob import glob
from astropy.io import fits 
i_images = glob(r"E:\MACRO\MCV\Images\*\*\*_i_*.fts")
i_images_2 = glob(r"E:\MACRO\MCV\Images\*\*_i_*.fts")
print(len(i_images))
print(len(i_images_2))

zpmag = 0
num_included = 0
for img in i_images:
    header = fits.getheader(img)
    if 'ZPMAG' in header:
        zpmag += header['ZPMAG']
        num_included += 1
for img in i_images_2:
    header = fits.getheader(img)
    if 'ZPMAG' in header:
        zpmag += header['ZPMAG']
        num_included += 1

if num_included > 0:
    print("Average ZPMAG:", zpmag / num_included)
else:
    print("No ZPMAG values found for i fitler in the headers.")
# Out:
# 43
# 3
# No ZPMAG values found for i fitler in the headers.

# %%
g_images = glob(r"E:\MACRO\MCV\Images\*\*\*_g_*.fts")
g_images_2 = glob(r"E:\MACRO\MCV\Images\*\*_g_*.fts")
print(len(g_images))
print(len(g_images_2))

zpmag = 0
num_included = 0
for img in g_images:
    header = fits.getheader(img)
    if 'ZPMAG' in header:
        zpmag += header['ZPMAG']
        num_included += 1
for img in g_images_2:
    header = fits.getheader(img)
    if 'ZPMAG' in header:
        zpmag += header['ZPMAG']
        num_included += 1
print("Average ZPMAG for g filter:", zpmag / num_included)
# Out:
# 6
# 0
# Average ZPMAG for g filter: 21.84211773392965

# %%
r_images = glob(r"E:\MACRO\MCV\Images\*\*\*_r_*.fts")
r_images_2 = glob(r"E:\MACRO\MCV\Images\*\*_r_*.fts")
print(len(r_images))
print(len(r_images_2))

zpmag = 0
num_included = 0
for img in r_images:
    header = fits.getheader(img)
    if 'ZPMAG' in header:
        zpmag += header['ZPMAG']
        num_included += 1
for img in r_images_2:
    header = fits.getheader(img)
    if 'ZPMAG' in header:
        zpmag += header['ZPMAG']
        num_included += 1
print("Average ZPMAG for r filter:", zpmag / num_included)
# Out:
# 57
# 0
# Average ZPMAG: 20.839567034245288

# %% [markdown]
# ## Photon/electron counts for a given mag difference

# %%
photon_counts_per_mag_diff_per_sec = [2.5**num for num in range(1, 21)]
photon_counts_per_mag_diff_per_sec = np.array(photon_counts_per_mag_diff_per_sec)
print(photon_counts_per_mag_diff_per_sec)
# Out:
# [2.50000000e+00 6.25000000e+00 1.56250000e+01 3.90625000e+01
#  9.76562500e+01 2.44140625e+02 6.10351562e+02 1.52587891e+03
#  3.81469727e+03 9.53674316e+03 2.38418579e+04 5.96046448e+04
#  1.49011612e+05 3.72529030e+05 9.31322575e+05 2.32830644e+06
#  5.82076609e+06 1.45519152e+07 3.63797881e+07 9.09494702e+07]

# %% [markdown]
# ## Associated mag error estimates

# %%
snr_1s = snr_est(photon_counts_per_mag_diff_per_sec * 1)
snr_10s = snr_est(photon_counts_per_mag_diff_per_sec * 10)
snr_30s = snr_est(photon_counts_per_mag_diff_per_sec * 30)
snr_60s = snr_est(photon_counts_per_mag_diff_per_sec * 60)
snr_120s = snr_est(photon_counts_per_mag_diff_per_sec * 120)
snr_300s = snr_est(photon_counts_per_mag_diff_per_sec * 300)

est_mag_errors_1s = mag_error(snr_1s)
est_mag_errors_10s = mag_error(snr_10s) 
est_mag_errors_30s = mag_error(snr_30s)
est_mag_errors_60s = mag_error(snr_60s)
est_mag_errors_120s = mag_error(snr_120s)
est_mag_errors_300s = mag_error(snr_300s)

for i in range(len(snr_1s)):
    print(f"Mag difference: {i+1}, SNR for 1s: {snr_1s[i]:.2f}, Mag error for 1s: {est_mag_errors_1s[i]:.4f}")
    print(f"Mag difference: {i+1}, SNR for 10s: {snr_10s[i]:.2f}, Mag error for 10s: {est_mag_errors_10s[i]:.4f}")
    print(f"Mag difference: {i+1}, SNR for 30s: {snr_30s[i]:.2f}, Mag error for 30s: {est_mag_errors_30s[i]:.4f}")
    print(f"Mag difference: {i+1}, SNR for 60s: {snr_60s[i]:.2f}, Mag error for 60s: {est_mag_errors_60s[i]:.4f}")
    print(f"Mag difference: {i+1}, SNR for 120s: {snr_120s[i]:.2f}, Mag error for 120s: {est_mag_errors_120s[i]:.4f}")
    print(f"Mag difference: {i+1}, SNR for 300s: {snr_300s[i]:.2f}, Mag error for 300s: {est_mag_errors_300s[i]:.4f}")
    print("")
# Out:
# Mag difference: 1, SNR for 1s: 1.58, Mag error for 1s: 0.6867
# Mag difference: 1, SNR for 10s: 5.00, Mag error for 10s: 0.2171
# Mag difference: 1, SNR for 30s: 8.66, Mag error for 30s: 0.1254
# Mag difference: 1, SNR for 60s: 12.25, Mag error for 60s: 0.0886
# Mag difference: 1, SNR for 120s: 17.32, Mag error for 120s: 0.0627
# Mag difference: 1, SNR for 300s: 27.39, Mag error for 300s: 0.0396
#
# Mag difference: 2, SNR for 1s: 2.50, Mag error for 1s: 0.4343
# Mag difference: 2, SNR for 10s: 7.91, Mag error for 10s: 0.1373
# Mag difference: 2, SNR for 30s: 13.69, Mag error for 30s: 0.0793
# Mag difference: 2, SNR for 60s: 19.36, Mag error for 60s: 0.0561
# Mag difference: 2, SNR for 120s: 27.39, Mag error for 120s: 0.0396
# Mag difference: 2, SNR for 300s: 43.30, Mag error for 300s: 0.0251
#
# Mag difference: 3, SNR for 1s: 3.95, Mag error for 1s: 0.2747
# Mag difference: 3, SNR for 10s: 12.50, Mag error for 10s: 0.0869
# Mag difference: 3, SNR for 30s: 21.65, Mag error for 30s: 0.0501
# Mag difference: 3, SNR for 60s: 30.62, Mag error for 60s: 0.0355
# Mag difference: 3, SNR for 120s: 43.30, Mag error for 120s: 0.0251
# Mag difference: 3, SNR for 300s: 68.47, Mag error for 300s: 0.0159
#
# Mag difference: 4, SNR for 1s: 6.25, Mag error for 1s: 0.1737
# Mag difference: 4, SNR for 10s: 19.76, Mag error for 10s: 0.0549
# Mag difference: 4, SNR for 30s: 34.23, Mag error for 30s: 0.0317
# Mag difference: 4, SNR for 60s: 48.41, Mag error for 60s: 0.0224
# Mag difference: 4, SNR for 120s: 68.47, Mag error for 120s: 0.0159
# Mag difference: 4, SNR for 300s: 108.25, Mag error for 300s: 0.0100
#
# Mag difference: 5, SNR for 1s: 9.88, Mag error for 1s: 0.1099
# Mag difference: 5, SNR for 10s: 31.25, Mag error for 10s: 0.0347
# Mag difference: 5, SNR for 30s: 54.13, Mag error for 30s: 0.0201
# Mag difference: 5, SNR for 60s: 76.55, Mag error for 60s: 0.0142
# Mag difference: 5, SNR for 120s: 108.25, Mag error for 120s: 0.0100
# Mag difference: 5, SNR for 300s: 171.16, Mag error for 300s: 0.0063
#
# Mag difference: 6, SNR for 1s: 15.62, Mag error for 1s: 0.0695
# Mag difference: 6, SNR for 10s: 49.41, Mag error for 10s: 0.0220
# Mag difference: 6, SNR for 30s: 85.58, Mag error for 30s: 0.0127
# Mag difference: 6, SNR for 60s: 121.03, Mag error for 60s: 0.0090
# Mag difference: 6, SNR for 120s: 171.16, Mag error for 120s: 0.0063
# Mag difference: 6, SNR for 300s: 270.63, Mag error for 300s: 0.0040
#
# Mag difference: 7, SNR for 1s: 24.71, Mag error for 1s: 0.0439
# Mag difference: 7, SNR for 10s: 78.12, Mag error for 10s: 0.0139
# Mag difference: 7, SNR for 30s: 135.32, Mag error for 30s: 0.0080
# Mag difference: 7, SNR for 60s: 191.37, Mag error for 60s: 0.0057
# Mag difference: 7, SNR for 120s: 270.63, Mag error for 120s: 0.0040
# Mag difference: 7, SNR for 300s: 427.91, Mag error for 300s: 0.0025
#
# Mag difference: 8, SNR for 1s: 39.06, Mag error for 1s: 0.0278
# Mag difference: 8, SNR for 10s: 123.53, Mag error for 10s: 0.0088
# Mag difference: 8, SNR for 30s: 213.95, Mag error for 30s: 0.0051
# Mag difference: 8, SNR for 60s: 302.58, Mag error for 60s: 0.0036
# Mag difference: 8, SNR for 120s: 427.91, Mag error for 120s: 0.0025
# Mag difference: 8, SNR for 300s: 676.58, Mag error for 300s: 0.0016
#
# Mag difference: 9, SNR for 1s: 61.76, Mag error for 1s: 0.0176
# Mag difference: 9, SNR for 10s: 195.31, Mag error for 10s: 0.0056
# Mag difference: 9, SNR for 30s: 338.29, Mag error for 30s: 0.0032
# Mag difference: 9, SNR for 60s: 478.42, Mag error for 60s: 0.0023
# Mag difference: 9, SNR for 120s: 676.58, Mag error for 120s: 0.0016
# Mag difference: 9, SNR for 300s: 1069.77, Mag error for 300s: 0.0010
#
# Mag difference: 10, SNR for 1s: 97.66, Mag error for 1s: 0.0111
# Mag difference: 10, SNR for 10s: 308.82, Mag error for 10s: 0.0035
# Mag difference: 10, SNR for 30s: 534.89, Mag error for 30s: 0.0020
# Mag difference: 10, SNR for 60s: 756.44, Mag error for 60s: 0.0014
# Mag difference: 10, SNR for 120s: 1069.77, Mag error for 120s: 0.0010
# Mag difference: 10, SNR for 300s: 1691.46, Mag error for 300s: 0.0006
#
# Mag difference: 11, SNR for 1s: 154.41, Mag error for 1s: 0.0070
# Mag difference: 11, SNR for 10s: 488.28, Mag error for 10s: 0.0022
# Mag difference: 11, SNR for 30s: 845.73, Mag error for 30s: 0.0013
# Mag difference: 11, SNR for 60s: 1196.04, Mag error for 60s: 0.0009
# Mag difference: 11, SNR for 120s: 1691.46, Mag error for 120s: 0.0006
# Mag difference: 11, SNR for 300s: 2674.43, Mag error for 300s: 0.0004
#
# Mag difference: 12, SNR for 1s: 244.14, Mag error for 1s: 0.0044
# Mag difference: 12, SNR for 10s: 772.04, Mag error for 10s: 0.0014
# Mag difference: 12, SNR for 30s: 1337.21, Mag error for 30s: 0.0008
# Mag difference: 12, SNR for 60s: 1891.11, Mag error for 60s: 0.0006
# Mag difference: 12, SNR for 120s: 2674.43, Mag error for 120s: 0.0004
# Mag difference: 12, SNR for 300s: 4228.64, Mag error for 300s: 0.0003
#
# Mag difference: 13, SNR for 1s: 386.02, Mag error for 1s: 0.0028
# Mag difference: 13, SNR for 10s: 1220.70, Mag error for 10s: 0.0009
# Mag difference: 13, SNR for 30s: 2114.32, Mag error for 30s: 0.0005
# Mag difference: 13, SNR for 60s: 2990.10, Mag error for 60s: 0.0004
# Mag difference: 13, SNR for 120s: 4228.64, Mag error for 120s: 0.0003
# Mag difference: 13, SNR for 300s: 6686.07, Mag error for 300s: 0.0002
#
# Mag difference: 14, SNR for 1s: 610.35, Mag error for 1s: 0.0018
# Mag difference: 14, SNR for 10s: 1930.10, Mag error for 10s: 0.0006
# Mag difference: 14, SNR for 30s: 3343.03, Mag error for 30s: 0.0003
# Mag difference: 14, SNR for 60s: 4727.76, Mag error for 60s: 0.0002
# Mag difference: 14, SNR for 120s: 6686.07, Mag error for 120s: 0.0002
# Mag difference: 14, SNR for 300s: 10571.60, Mag error for 300s: 0.0001
#
# Mag difference: 15, SNR for 1s: 965.05, Mag error for 1s: 0.0011
# Mag difference: 15, SNR for 10s: 3051.76, Mag error for 10s: 0.0004
# Mag difference: 15, SNR for 30s: 5285.80, Mag error for 30s: 0.0002
# Mag difference: 15, SNR for 60s: 7475.25, Mag error for 60s: 0.0001
# Mag difference: 15, SNR for 120s: 10571.60, Mag error for 120s: 0.0001
# Mag difference: 15, SNR for 300s: 16715.17, Mag error for 300s: 0.0001
#
# Mag difference: 16, SNR for 1s: 1525.88, Mag error for 1s: 0.0007
# Mag difference: 16, SNR for 10s: 4825.25, Mag error for 10s: 0.0002
# Mag difference: 16, SNR for 30s: 8357.58, Mag error for 30s: 0.0001
# Mag difference: 16, SNR for 60s: 11819.41, Mag error for 60s: 0.0001
# Mag difference: 16, SNR for 120s: 16715.17, Mag error for 120s: 0.0001
# Mag difference: 16, SNR for 300s: 26429.00, Mag error for 300s: 0.0000
#
# Mag difference: 17, SNR for 1s: 2412.63, Mag error for 1s: 0.0005
# Mag difference: 17, SNR for 10s: 7629.39, Mag error for 10s: 0.0001
# Mag difference: 17, SNR for 30s: 13214.50, Mag error for 30s: 0.0001
# Mag difference: 17, SNR for 60s: 18688.12, Mag error for 60s: 0.0001
# Mag difference: 17, SNR for 120s: 26429.00, Mag error for 120s: 0.0000
# Mag difference: 17, SNR for 300s: 41787.91, Mag error for 300s: 0.0000
#
# Mag difference: 18, SNR for 1s: 3814.70, Mag error for 1s: 0.0003
# Mag difference: 18, SNR for 10s: 12063.13, Mag error for 10s: 0.0001
# Mag difference: 18, SNR for 30s: 20893.96, Mag error for 30s: 0.0001
# Mag difference: 18, SNR for 60s: 29548.52, Mag error for 60s: 0.0000
# Mag difference: 18, SNR for 120s: 41787.91, Mag error for 120s: 0.0000
# Mag difference: 18, SNR for 300s: 66072.49, Mag error for 300s: 0.0000
#
# Mag difference: 19, SNR for 1s: 6031.57, Mag error for 1s: 0.0002
# Mag difference: 19, SNR for 10s: 19073.49, Mag error for 10s: 0.0001
# Mag difference: 19, SNR for 30s: 33036.25, Mag error for 30s: 0.0000
# Mag difference: 19, SNR for 60s: 46720.31, Mag error for 60s: 0.0000
# Mag difference: 19, SNR for 120s: 66072.49, Mag error for 120s: 0.0000
# Mag difference: 19, SNR for 300s: 104469.79, Mag error for 300s: 0.0000
#
# Mag difference: 20, SNR for 1s: 9536.74, Mag error for 1s: 0.0001
# Mag difference: 20, SNR for 10s: 30157.83, Mag error for 10s: 0.0000
# Mag difference: 20, SNR for 30s: 52234.89, Mag error for 30s: 0.0000
# Mag difference: 20, SNR for 60s: 73871.29, Mag error for 60s: 0.0000
# Mag difference: 20, SNR for 120s: 104469.79, Mag error for 120s: 0.0000
# Mag difference: 20, SNR for 300s: 165181.24, Mag error for 300s: 0.0000

# %% [markdown]
# ## $\Delta m = 21 - 2.5log_{10}(photons/s \pm transit\ depth \%)$

# %%
transit_depths = [0.01, 0.1, 0.5, 1.0, 2.0, 5.0, 10.0, 25.0, 50.0]  # in percentage
delta_mag_results = {}
for depth in transit_depths:
    print(f"Transit depth: {depth}%")
    for i, counts in enumerate(photon_counts_per_mag_diff_per_sec):
        m = 21 - 2.5 * np.log10(counts)
        # delta_m_P = 21 - 2.5 * np.log10(counts * (1 + depth / 100)) - m
        delta_m_M = 21 - 2.5 * np.log10(counts * (1 - depth / 100)) - m

        # print(f"Mag difference: {i+1}, Δm+ : {delta_m_P:.4f}, Δm- : {delta_m_M:.4f}, m: {m:.4f}")
        print(f"Δm- : {delta_m_M:.4f}")
        if i == 0:
            delta_mag_results[depth] = {"delta_m_M": [delta_m_M], "m": [m], "mag_diff": [i+1], "transit_depths": [depth], "photon_counts": [counts]}
            break
    print("")
# Out:
# Transit depth: 0.01%
# Δm- : 0.0001
#
# Transit depth: 0.1%
# Δm- : 0.0011
#
# Transit depth: 0.5%
# Δm- : 0.0054
#
# Transit depth: 1.0%
# Δm- : 0.0109
#
# Transit depth: 2.0%
# Δm- : 0.0219
#
# Transit depth: 5.0%
# Δm- : 0.0557
#
# Transit depth: 10.0%
# Δm- : 0.1144
#
# Transit depth: 25.0%
# Δm- : 0.3123
#
# Transit depth: 50.0%
# Δm- : 0.7526

# %% [markdown]
# ## Estimating 10% flux on center pixel

# %%
full_well = 65535.0
counts_per_sec_10_percent = photon_counts_per_mag_diff_per_sec*0.1
saturation_times = full_well / counts_per_sec_10_percent
for i, time in enumerate(saturation_times):
    print(f"Mag difference: {i+1}, Saturation time (s): {time:.2f}")
# Out:
# Mag difference: 1, Saturation time (s): 262140.00
# Mag difference: 2, Saturation time (s): 104856.00
# Mag difference: 3, Saturation time (s): 41942.40
# Mag difference: 4, Saturation time (s): 16776.96
# Mag difference: 5, Saturation time (s): 6710.78
# Mag difference: 6, Saturation time (s): 2684.31
# Mag difference: 7, Saturation time (s): 1073.73
# Mag difference: 8, Saturation time (s): 429.49
# Mag difference: 9, Saturation time (s): 171.80
# Mag difference: 10, Saturation time (s): 68.72
# Mag difference: 11, Saturation time (s): 27.49
# Mag difference: 12, Saturation time (s): 10.99
# Mag difference: 13, Saturation time (s): 4.40
# Mag difference: 14, Saturation time (s): 1.76
# Mag difference: 15, Saturation time (s): 0.70
# Mag difference: 16, Saturation time (s): 0.28
# Mag difference: 17, Saturation time (s): 0.11
# Mag difference: 18, Saturation time (s): 0.05
# Mag difference: 19, Saturation time (s): 0.02
# Mag difference: 20, Saturation time (s): 0.01

# %% [markdown]
# ## Estimating 25% flux on center pixel

# %%
saturation_times_25 = full_well / (photon_counts_per_mag_diff_per_sec*0.25)
for i, time in enumerate(saturation_times_25):
    print(f"Mag difference: {i+1}, Saturation time (s) at 25% flux: {time:.2f}")
# Out:
# Mag difference: 1, Saturation time (s) at 25% flux: 104856.00
# Mag difference: 2, Saturation time (s) at 25% flux: 41942.40
# Mag difference: 3, Saturation time (s) at 25% flux: 16776.96
# Mag difference: 4, Saturation time (s) at 25% flux: 6710.78
# Mag difference: 5, Saturation time (s) at 25% flux: 2684.31
# Mag difference: 6, Saturation time (s) at 25% flux: 1073.73
# Mag difference: 7, Saturation time (s) at 25% flux: 429.49
# Mag difference: 8, Saturation time (s) at 25% flux: 171.80
# Mag difference: 9, Saturation time (s) at 25% flux: 68.72
# Mag difference: 10, Saturation time (s) at 25% flux: 27.49
# Mag difference: 11, Saturation time (s) at 25% flux: 10.99
# Mag difference: 12, Saturation time (s) at 25% flux: 4.40
# Mag difference: 13, Saturation time (s) at 25% flux: 1.76
# Mag difference: 14, Saturation time (s) at 25% flux: 0.70
# Mag difference: 15, Saturation time (s) at 25% flux: 0.28
# Mag difference: 16, Saturation time (s) at 25% flux: 0.11
# Mag difference: 17, Saturation time (s) at 25% flux: 0.05
# Mag difference: 18, Saturation time (s) at 25% flux: 0.02
# Mag difference: 19, Saturation time (s) at 25% flux: 0.01
# Mag difference: 20, Saturation time (s) at 25% flux: 0.00

# %% [markdown]
# ## Peak pixel at ~1.03-1.07 airmass appears to range around 1.5-4% actually, so our times can be longer

# %%
import pandas as pd
data = pd.read_csv(r"E:\school\2025 Fall\Observational Astro\SNR - Mag goals\AN_UMa_r-i_few_stars.csv")

t1_peaks = np.array(data['Peak_T1'].values)
t1_sky = np.array(data['Source-Sky_T1'].values)

c2_peaks = np.array(data['Peak_C2'].values)
c2_sky = np.array(data['Source-Sky_C2'].values)

c3_peaks = np.array(data['Peak_C3'].values)
c3_sky = np.array(data['Source-Sky_C3'].values)

c4_peaks = np.array(data['Peak_C4'].values)
c4_sky = np.array(data['Source-Sky_C4'].values)

c5_peaks = np.array(data['Peak_C5'].values)
c5_sky = np.array(data['Source-Sky_C5'].values)

t1_peak_percent = (t1_peaks / t1_sky * 100)
c2_peak_percent = (c2_peaks / c2_sky * 100)
c3_peak_percent = (c3_peaks / c3_sky * 100)
c4_peak_percent = (c4_peaks / c4_sky * 100)
c5_peak_percent = (c5_peaks / c5_sky * 100)

mean_t1 = np.mean(t1_peak_percent)
mean_c2 = np.mean(c2_peak_percent)
mean_c3 = np.mean(c3_peak_percent)
mean_c4 = np.mean(c4_peak_percent)
mean_c5 = np.mean(c5_peak_percent)

max_t1 = np.max(t1_peak_percent)
max_c2 = np.max(c2_peak_percent)
max_c3 = np.max(c3_peak_percent)
max_c4 = np.max(c4_peak_percent)
max_c5 = np.max(c5_peak_percent)

min_t1 = np.min(t1_peak_percent)
min_c2 = np.min(c2_peak_percent)    
min_c3 = np.min(c3_peak_percent)
min_c4 = np.min(c4_peak_percent)
min_c5 = np.min(c5_peak_percent)

print("T1 Mean Peak %:", mean_t1, "Max Peak %:", max_t1, "Min Peak %:", min_t1)
print("C2 Mean Peak %:", mean_c2, "Max Peak %:", max_c2, "Min Peak %:", min_c2)
print("C3 Mean Peak %:", mean_c3, "Max Peak %:", max_c3, "Min Peak %:", min_c3)
print("C4 Mean Peak %:", mean_c4, "Max Peak %:", max_c4, "Min Peak %:", min_c4)
print("C5 Mean Peak %:", mean_c5, "Max Peak %:", max_c5, "Min Peak %:", min_c5)
# Out:
# T1 Mean Peak %: 2.758971714267329 Max Peak %: 4.340521685092317 Min Peak %: 2.0551799152155112
# C2 Mean Peak %: 3.5604927006260594 Max Peak %: 5.56713092796591 Min Peak %: 2.1630258074712794
# C3 Mean Peak %: 3.352638136970748 Max Peak %: 5.226239823192906 Min Peak %: 2.0284122547773014
# C4 Mean Peak %: 3.507246821022393 Max Peak %: 5.357621243661197 Min Peak %: 2.1789910265671772
# C5 Mean Peak %: 3.607076624617365 Max Peak %: 5.520219832131214 Min Peak %: 2.2634184378564015

# %% [markdown]
# ## Better estimates

# %%
full_well = 65535.0
counts_per_sec_2_percent = photon_counts_per_mag_diff_per_sec*0.02
saturation_times_2_percent = full_well / counts_per_sec_2_percent
for i, time in enumerate(saturation_times_2_percent):
    print(f"Mag difference at 2%: {i+1}, Saturation time (s): {time:.2f}")

print("")

counts_per_sec_6_percent = photon_counts_per_mag_diff_per_sec*0.06
saturation_times_6_percent = full_well / counts_per_sec_6_percent
for i, time in enumerate(saturation_times_6_percent):
    print(f"Mag difference at 6%: {i+1}, Saturation time (s): {time:.2f}")
# Out:
# Mag difference at 2%: 1, Saturation time (s): 1310700.00
# Mag difference at 2%: 2, Saturation time (s): 524280.00
# Mag difference at 2%: 3, Saturation time (s): 209712.00
# Mag difference at 2%: 4, Saturation time (s): 83884.80
# Mag difference at 2%: 5, Saturation time (s): 33553.92
# Mag difference at 2%: 6, Saturation time (s): 13421.57
# Mag difference at 2%: 7, Saturation time (s): 5368.63
# Mag difference at 2%: 8, Saturation time (s): 2147.45
# Mag difference at 2%: 9, Saturation time (s): 858.98
# Mag difference at 2%: 10, Saturation time (s): 343.59
# Mag difference at 2%: 11, Saturation time (s): 137.44
# Mag difference at 2%: 12, Saturation time (s): 54.97
# Mag difference at 2%: 13, Saturation time (s): 21.99
# Mag difference at 2%: 14, Saturation time (s): 8.80
# Mag difference at 2%: 15, Saturation time (s): 3.52
# Mag difference at 2%: 16, Saturation time (s): 1.41
# Mag difference at 2%: 17, Saturation time (s): 0.56
# Mag difference at 2%: 18, Saturation time (s): 0.23
# Mag difference at 2%: 19, Saturation time (s): 0.09
# Mag difference at 2%: 20, Saturation time (s): 0.04
#
# Mag difference at 6%: 1, Saturation time (s): 436900.00
# Mag difference at 6%: 2, Saturation time (s): 174760.00
# Mag difference at 6%: 3, Saturation time (s): 69904.00
# Mag difference at 6%: 4, Saturation time (s): 27961.60
# Mag difference at 6%: 5, Saturation time (s): 11184.64
# Mag difference at 6%: 6, Saturation time (s): 4473.86
# Mag difference at 6%: 7, Saturation time (s): 1789.54
# Mag difference at 6%: 8, Saturation time (s): 715.82
# Mag difference at 6%: 9, Saturation time (s): 286.33
# Mag difference at 6%: 10, Saturation time (s): 114.53
# Mag difference at 6%: 11, Saturation time (s): 45.81
# Mag difference at 6%: 12, Saturation time (s): 18.32
# Mag difference at 6%: 13, Saturation time (s): 7.33
# Mag difference at 6%: 14, Saturation time (s): 2.93
# Mag difference at 6%: 15, Saturation time (s): 1.17
# Mag difference at 6%: 16, Saturation time (s): 0.47
# Mag difference at 6%: 17, Saturation time (s): 0.19
# Mag difference at 6%: 18, Saturation time (s): 0.08
# Mag difference at 6%: 19, Saturation time (s): 0.03
# Mag difference at 6%: 20, Saturation time (s): 0.01

# %% [markdown]
# ## SNR where $\Delta m = \sigma_m$

# %%
min_snrs = []
snr_needed = []

for i in delta_mag_results:
    snr_val = min_snr(delta_mag_results[i]["delta_m_M"][0])
    snr_goal = snr_val * 3

    snr_val = round(snr_val, 2)
    snr_goal = round(snr_goal, 2)

    min_snrs.append(snr_val)
    snr_needed.append(snr_goal)

acceptable_snrs = [[], [], [], [], [], [], [], [], []]  # (SNR, exposure time, mag difference from zero point)
exposures = [1, 10, 30, 60, 120, 300]
for i, snr in enumerate(snr_needed):
    for t, snrs in enumerate([snr_1s, snr_10s, snr_30s, snr_60s, snr_120s, snr_300s]):
        for j, actual_snr in enumerate(snrs):
            if snr <= actual_snr and exposures[t] <= saturation_times_6_percent[j]:
                acceptable_snrs[i].append((actual_snr, exposures[t], j + 1))

for i in range(len(acceptable_snrs)):
    print(f"Number of acceptable SNRs for transit depth {transit_depths[i]}%: {len(acceptable_snrs[i])}")

print("")

for i, depth in enumerate(transit_depths):
    if len(acceptable_snrs[i]) == 0:
        print(f"No acceptable exposure times found for transit depth {depth}%")
        print("")
    else:    
        print(f"Transit depth: {depth}%, SNR at Δm = σ_m: {min_snrs[i]}, SNR needed for 3σ detection: {snr_needed[i]}")
        print("Acceptable combinations:")
        for snr in acceptable_snrs[i]:
            print(f"SNR: {snr[0]:.2f}, Exposure time: {snr[1]}s, Mag difference from zero point: {snr[2]}, Mag (~g zpmag = 22): {22 - snr[2]}, Mag (~i zpmag = 19): {19 - snr[2]}")
        print("")
# Out:
# Number of acceptable SNRs for transit depth 0.01%: 0
# Number of acceptable SNRs for transit depth 0.1%: 0
# Number of acceptable SNRs for transit depth 0.5%: 7
# Number of acceptable SNRs for transit depth 1.0%: 16
# Number of acceptable SNRs for transit depth 2.0%: 25
# Number of acceptable SNRs for transit depth 5.0%: 37
# Number of acceptable SNRs for transit depth 10.0%: 46
# Number of acceptable SNRs for transit depth 25.0%: 57
# Number of acceptable SNRs for transit depth 50.0%: 62
#
# No acceptable exposure times found for transit depth 0.01%
#
# No acceptable exposure times found for transit depth 0.1%
#
# Transit depth: 0.5%, SNR at Δm = σ_m: 199.49, SNR needed for 3σ detection: 598.48
# Acceptable combinations:
# SNR: 610.35, Exposure time: 1s, Mag difference from zero point: 14, Mag (~g zpmag = 22): 8, Mag (~i zpmag = 19): 5
# SNR: 965.05, Exposure time: 1s, Mag difference from zero point: 15, Mag (~g zpmag = 22): 7, Mag (~i zpmag = 19): 4
# SNR: 772.04, Exposure time: 10s, Mag difference from zero point: 12, Mag (~g zpmag = 22): 10, Mag (~i zpmag = 19): 7
# SNR: 845.73, Exposure time: 30s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 756.44, Exposure time: 60s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 676.58, Exposure time: 120s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 676.58, Exposure time: 300s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
#
# Transit depth: 1.0%, SNR at Δm = σ_m: 99.5, SNR needed for 3σ detection: 298.49
# Acceptable combinations:
# SNR: 386.02, Exposure time: 1s, Mag difference from zero point: 13, Mag (~g zpmag = 22): 9, Mag (~i zpmag = 19): 6
# SNR: 610.35, Exposure time: 1s, Mag difference from zero point: 14, Mag (~g zpmag = 22): 8, Mag (~i zpmag = 19): 5
# SNR: 965.05, Exposure time: 1s, Mag difference from zero point: 15, Mag (~g zpmag = 22): 7, Mag (~i zpmag = 19): 4
# SNR: 308.82, Exposure time: 10s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 488.28, Exposure time: 10s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 772.04, Exposure time: 10s, Mag difference from zero point: 12, Mag (~g zpmag = 22): 10, Mag (~i zpmag = 19): 7
# SNR: 338.29, Exposure time: 30s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 534.89, Exposure time: 30s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 845.73, Exposure time: 30s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 302.58, Exposure time: 60s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 478.42, Exposure time: 60s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 756.44, Exposure time: 60s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 427.91, Exposure time: 120s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 676.58, Exposure time: 120s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 427.91, Exposure time: 300s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 676.58, Exposure time: 300s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
#
# Transit depth: 2.0%, SNR at Δm = σ_m: 49.5, SNR needed for 3σ detection: 148.49
# Acceptable combinations:
# SNR: 154.41, Exposure time: 1s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 244.14, Exposure time: 1s, Mag difference from zero point: 12, Mag (~g zpmag = 22): 10, Mag (~i zpmag = 19): 7
# SNR: 386.02, Exposure time: 1s, Mag difference from zero point: 13, Mag (~g zpmag = 22): 9, Mag (~i zpmag = 19): 6
# SNR: 610.35, Exposure time: 1s, Mag difference from zero point: 14, Mag (~g zpmag = 22): 8, Mag (~i zpmag = 19): 5
# SNR: 965.05, Exposure time: 1s, Mag difference from zero point: 15, Mag (~g zpmag = 22): 7, Mag (~i zpmag = 19): 4
# SNR: 195.31, Exposure time: 10s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 308.82, Exposure time: 10s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 488.28, Exposure time: 10s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 772.04, Exposure time: 10s, Mag difference from zero point: 12, Mag (~g zpmag = 22): 10, Mag (~i zpmag = 19): 7
# SNR: 213.95, Exposure time: 30s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 338.29, Exposure time: 30s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 534.89, Exposure time: 30s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 845.73, Exposure time: 30s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 191.37, Exposure time: 60s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 302.58, Exposure time: 60s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 478.42, Exposure time: 60s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 756.44, Exposure time: 60s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 171.16, Exposure time: 120s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 270.63, Exposure time: 120s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 427.91, Exposure time: 120s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 676.58, Exposure time: 120s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 171.16, Exposure time: 300s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 270.63, Exposure time: 300s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 427.91, Exposure time: 300s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 676.58, Exposure time: 300s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
#
# Transit depth: 5.0%, SNR at Δm = σ_m: 19.5, SNR needed for 3σ detection: 58.49
# Acceptable combinations:
# SNR: 61.76, Exposure time: 1s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 97.66, Exposure time: 1s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 154.41, Exposure time: 1s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 244.14, Exposure time: 1s, Mag difference from zero point: 12, Mag (~g zpmag = 22): 10, Mag (~i zpmag = 19): 7
# SNR: 386.02, Exposure time: 1s, Mag difference from zero point: 13, Mag (~g zpmag = 22): 9, Mag (~i zpmag = 19): 6
# SNR: 610.35, Exposure time: 1s, Mag difference from zero point: 14, Mag (~g zpmag = 22): 8, Mag (~i zpmag = 19): 5
# SNR: 965.05, Exposure time: 1s, Mag difference from zero point: 15, Mag (~g zpmag = 22): 7, Mag (~i zpmag = 19): 4
# SNR: 78.12, Exposure time: 10s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 123.53, Exposure time: 10s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 195.31, Exposure time: 10s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 308.82, Exposure time: 10s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 488.28, Exposure time: 10s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 772.04, Exposure time: 10s, Mag difference from zero point: 12, Mag (~g zpmag = 22): 10, Mag (~i zpmag = 19): 7
# SNR: 85.58, Exposure time: 30s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 135.32, Exposure time: 30s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 213.95, Exposure time: 30s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 338.29, Exposure time: 30s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 534.89, Exposure time: 30s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 845.73, Exposure time: 30s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 76.55, Exposure time: 60s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 121.03, Exposure time: 60s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 191.37, Exposure time: 60s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 302.58, Exposure time: 60s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 478.42, Exposure time: 60s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 756.44, Exposure time: 60s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 68.47, Exposure time: 120s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 108.25, Exposure time: 120s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 171.16, Exposure time: 120s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 270.63, Exposure time: 120s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 427.91, Exposure time: 120s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 676.58, Exposure time: 120s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 68.47, Exposure time: 300s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 108.25, Exposure time: 300s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 171.16, Exposure time: 300s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 270.63, Exposure time: 300s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 427.91, Exposure time: 300s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 676.58, Exposure time: 300s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
#
# Transit depth: 10.0%, SNR at Δm = σ_m: 9.49, SNR needed for 3σ detection: 28.47
# Acceptable combinations:
# SNR: 39.06, Exposure time: 1s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 61.76, Exposure time: 1s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 97.66, Exposure time: 1s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 154.41, Exposure time: 1s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 244.14, Exposure time: 1s, Mag difference from zero point: 12, Mag (~g zpmag = 22): 10, Mag (~i zpmag = 19): 7
# SNR: 386.02, Exposure time: 1s, Mag difference from zero point: 13, Mag (~g zpmag = 22): 9, Mag (~i zpmag = 19): 6
# SNR: 610.35, Exposure time: 1s, Mag difference from zero point: 14, Mag (~g zpmag = 22): 8, Mag (~i zpmag = 19): 5
# SNR: 965.05, Exposure time: 1s, Mag difference from zero point: 15, Mag (~g zpmag = 22): 7, Mag (~i zpmag = 19): 4
# SNR: 31.25, Exposure time: 10s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 49.41, Exposure time: 10s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 78.12, Exposure time: 10s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 123.53, Exposure time: 10s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 195.31, Exposure time: 10s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 308.82, Exposure time: 10s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 488.28, Exposure time: 10s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 772.04, Exposure time: 10s, Mag difference from zero point: 12, Mag (~g zpmag = 22): 10, Mag (~i zpmag = 19): 7
# SNR: 34.23, Exposure time: 30s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 54.13, Exposure time: 30s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 85.58, Exposure time: 30s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 135.32, Exposure time: 30s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 213.95, Exposure time: 30s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 338.29, Exposure time: 30s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 534.89, Exposure time: 30s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 845.73, Exposure time: 30s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 30.62, Exposure time: 60s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 48.41, Exposure time: 60s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 76.55, Exposure time: 60s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 121.03, Exposure time: 60s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 191.37, Exposure time: 60s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 302.58, Exposure time: 60s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 478.42, Exposure time: 60s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 756.44, Exposure time: 60s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 43.30, Exposure time: 120s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 68.47, Exposure time: 120s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 108.25, Exposure time: 120s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 171.16, Exposure time: 120s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 270.63, Exposure time: 120s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 427.91, Exposure time: 120s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 676.58, Exposure time: 120s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 43.30, Exposure time: 300s, Mag difference from zero point: 2, Mag (~g zpmag = 22): 20, Mag (~i zpmag = 19): 17
# SNR: 68.47, Exposure time: 300s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 108.25, Exposure time: 300s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 171.16, Exposure time: 300s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 270.63, Exposure time: 300s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 427.91, Exposure time: 300s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 676.58, Exposure time: 300s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
#
# Transit depth: 25.0%, SNR at Δm = σ_m: 3.48, SNR needed for 3σ detection: 10.43
# Acceptable combinations:
# SNR: 15.62, Exposure time: 1s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 24.71, Exposure time: 1s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 39.06, Exposure time: 1s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 61.76, Exposure time: 1s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 97.66, Exposure time: 1s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 154.41, Exposure time: 1s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 244.14, Exposure time: 1s, Mag difference from zero point: 12, Mag (~g zpmag = 22): 10, Mag (~i zpmag = 19): 7
# SNR: 386.02, Exposure time: 1s, Mag difference from zero point: 13, Mag (~g zpmag = 22): 9, Mag (~i zpmag = 19): 6
# SNR: 610.35, Exposure time: 1s, Mag difference from zero point: 14, Mag (~g zpmag = 22): 8, Mag (~i zpmag = 19): 5
# SNR: 965.05, Exposure time: 1s, Mag difference from zero point: 15, Mag (~g zpmag = 22): 7, Mag (~i zpmag = 19): 4
# SNR: 12.50, Exposure time: 10s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 19.76, Exposure time: 10s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 31.25, Exposure time: 10s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 49.41, Exposure time: 10s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 78.12, Exposure time: 10s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 123.53, Exposure time: 10s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 195.31, Exposure time: 10s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 308.82, Exposure time: 10s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 488.28, Exposure time: 10s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 772.04, Exposure time: 10s, Mag difference from zero point: 12, Mag (~g zpmag = 22): 10, Mag (~i zpmag = 19): 7
# SNR: 13.69, Exposure time: 30s, Mag difference from zero point: 2, Mag (~g zpmag = 22): 20, Mag (~i zpmag = 19): 17
# SNR: 21.65, Exposure time: 30s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 34.23, Exposure time: 30s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 54.13, Exposure time: 30s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 85.58, Exposure time: 30s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 135.32, Exposure time: 30s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 213.95, Exposure time: 30s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 338.29, Exposure time: 30s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 534.89, Exposure time: 30s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 845.73, Exposure time: 30s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 12.25, Exposure time: 60s, Mag difference from zero point: 1, Mag (~g zpmag = 22): 21, Mag (~i zpmag = 19): 18
# SNR: 19.36, Exposure time: 60s, Mag difference from zero point: 2, Mag (~g zpmag = 22): 20, Mag (~i zpmag = 19): 17
# SNR: 30.62, Exposure time: 60s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 48.41, Exposure time: 60s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 76.55, Exposure time: 60s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 121.03, Exposure time: 60s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 191.37, Exposure time: 60s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 302.58, Exposure time: 60s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 478.42, Exposure time: 60s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 756.44, Exposure time: 60s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 17.32, Exposure time: 120s, Mag difference from zero point: 1, Mag (~g zpmag = 22): 21, Mag (~i zpmag = 19): 18
# SNR: 27.39, Exposure time: 120s, Mag difference from zero point: 2, Mag (~g zpmag = 22): 20, Mag (~i zpmag = 19): 17
# SNR: 43.30, Exposure time: 120s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 68.47, Exposure time: 120s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 108.25, Exposure time: 120s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 171.16, Exposure time: 120s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 270.63, Exposure time: 120s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 427.91, Exposure time: 120s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 676.58, Exposure time: 120s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 27.39, Exposure time: 300s, Mag difference from zero point: 1, Mag (~g zpmag = 22): 21, Mag (~i zpmag = 19): 18
# SNR: 43.30, Exposure time: 300s, Mag difference from zero point: 2, Mag (~g zpmag = 22): 20, Mag (~i zpmag = 19): 17
# SNR: 68.47, Exposure time: 300s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 108.25, Exposure time: 300s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 171.16, Exposure time: 300s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 270.63, Exposure time: 300s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 427.91, Exposure time: 300s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 676.58, Exposure time: 300s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
#
# Transit depth: 50.0%, SNR at Δm = σ_m: 1.44, SNR needed for 3σ detection: 4.33
# Acceptable combinations:
# SNR: 6.25, Exposure time: 1s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 9.88, Exposure time: 1s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 15.62, Exposure time: 1s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 24.71, Exposure time: 1s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 39.06, Exposure time: 1s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 61.76, Exposure time: 1s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 97.66, Exposure time: 1s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 154.41, Exposure time: 1s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 244.14, Exposure time: 1s, Mag difference from zero point: 12, Mag (~g zpmag = 22): 10, Mag (~i zpmag = 19): 7
# SNR: 386.02, Exposure time: 1s, Mag difference from zero point: 13, Mag (~g zpmag = 22): 9, Mag (~i zpmag = 19): 6
# SNR: 610.35, Exposure time: 1s, Mag difference from zero point: 14, Mag (~g zpmag = 22): 8, Mag (~i zpmag = 19): 5
# SNR: 965.05, Exposure time: 1s, Mag difference from zero point: 15, Mag (~g zpmag = 22): 7, Mag (~i zpmag = 19): 4
# SNR: 5.00, Exposure time: 10s, Mag difference from zero point: 1, Mag (~g zpmag = 22): 21, Mag (~i zpmag = 19): 18
# SNR: 7.91, Exposure time: 10s, Mag difference from zero point: 2, Mag (~g zpmag = 22): 20, Mag (~i zpmag = 19): 17
# SNR: 12.50, Exposure time: 10s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 19.76, Exposure time: 10s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 31.25, Exposure time: 10s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 49.41, Exposure time: 10s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 78.12, Exposure time: 10s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 123.53, Exposure time: 10s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 195.31, Exposure time: 10s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 308.82, Exposure time: 10s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 488.28, Exposure time: 10s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 772.04, Exposure time: 10s, Mag difference from zero point: 12, Mag (~g zpmag = 22): 10, Mag (~i zpmag = 19): 7
# SNR: 8.66, Exposure time: 30s, Mag difference from zero point: 1, Mag (~g zpmag = 22): 21, Mag (~i zpmag = 19): 18
# SNR: 13.69, Exposure time: 30s, Mag difference from zero point: 2, Mag (~g zpmag = 22): 20, Mag (~i zpmag = 19): 17
# SNR: 21.65, Exposure time: 30s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 34.23, Exposure time: 30s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 54.13, Exposure time: 30s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 85.58, Exposure time: 30s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 135.32, Exposure time: 30s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 213.95, Exposure time: 30s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 338.29, Exposure time: 30s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 534.89, Exposure time: 30s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 845.73, Exposure time: 30s, Mag difference from zero point: 11, Mag (~g zpmag = 22): 11, Mag (~i zpmag = 19): 8
# SNR: 12.25, Exposure time: 60s, Mag difference from zero point: 1, Mag (~g zpmag = 22): 21, Mag (~i zpmag = 19): 18
# SNR: 19.36, Exposure time: 60s, Mag difference from zero point: 2, Mag (~g zpmag = 22): 20, Mag (~i zpmag = 19): 17
# SNR: 30.62, Exposure time: 60s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 48.41, Exposure time: 60s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 76.55, Exposure time: 60s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 121.03, Exposure time: 60s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 191.37, Exposure time: 60s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 302.58, Exposure time: 60s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 478.42, Exposure time: 60s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 756.44, Exposure time: 60s, Mag difference from zero point: 10, Mag (~g zpmag = 22): 12, Mag (~i zpmag = 19): 9
# SNR: 17.32, Exposure time: 120s, Mag difference from zero point: 1, Mag (~g zpmag = 22): 21, Mag (~i zpmag = 19): 18
# SNR: 27.39, Exposure time: 120s, Mag difference from zero point: 2, Mag (~g zpmag = 22): 20, Mag (~i zpmag = 19): 17
# SNR: 43.30, Exposure time: 120s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 68.47, Exposure time: 120s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 108.25, Exposure time: 120s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 171.16, Exposure time: 120s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 270.63, Exposure time: 120s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 427.91, Exposure time: 120s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
# SNR: 676.58, Exposure time: 120s, Mag difference from zero point: 9, Mag (~g zpmag = 22): 13, Mag (~i zpmag = 19): 10
# SNR: 27.39, Exposure time: 300s, Mag difference from zero point: 1, Mag (~g zpmag = 22): 21, Mag (~i zpmag = 19): 18
# SNR: 43.30, Exposure time: 300s, Mag difference from zero point: 2, Mag (~g zpmag = 22): 20, Mag (~i zpmag = 19): 17
# SNR: 68.47, Exposure time: 300s, Mag difference from zero point: 3, Mag (~g zpmag = 22): 19, Mag (~i zpmag = 19): 16
# SNR: 108.25, Exposure time: 300s, Mag difference from zero point: 4, Mag (~g zpmag = 22): 18, Mag (~i zpmag = 19): 15
# SNR: 171.16, Exposure time: 300s, Mag difference from zero point: 5, Mag (~g zpmag = 22): 17, Mag (~i zpmag = 19): 14
# SNR: 270.63, Exposure time: 300s, Mag difference from zero point: 6, Mag (~g zpmag = 22): 16, Mag (~i zpmag = 19): 13
# SNR: 427.91, Exposure time: 300s, Mag difference from zero point: 7, Mag (~g zpmag = 22): 15, Mag (~i zpmag = 19): 12
# SNR: 676.58, Exposure time: 300s, Mag difference from zero point: 8, Mag (~g zpmag = 22): 14, Mag (~i zpmag = 19): 11
